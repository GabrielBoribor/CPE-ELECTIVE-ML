# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielBoribor/CPE-ELECTIVE-ML/blob/main/TINKERCADDDDDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
unsigned const int A = 13;
unsigned const int B = 12;
unsigned const int C = 11;
unsigned const int D = 10;
unsigned const int E = 9;
unsigned const int F = 8;
unsigned const int G = 7;
int buttonState = 0;
const int ButtonPin = 2; // Make sure to uncomment this if necessary

void setup() {
  pinMode(A, OUTPUT);
  pinMode(B, OUTPUT);
  pinMode(C, OUTPUT);
  pinMode(D, OUTPUT);
  pinMode(E, OUTPUT);
  pinMode(F, OUTPUT);
  pinMode(G, OUTPUT);
  pinMode(A0, INPUT); // PotentioMETER
  pinMode(ButtonPin, INPUT_PULLUP); // Uncomment this if necessary
}

void loop() {
  int Delay = analogRead(A0);
  num_0();
  delay(Delay);
  num_1();
  delay(Delay);
  num_2();
  delay(Delay);
  num_3();
  delay(Delay);
  num_4();
  delay(Delay);
  num_5();
  delay(Delay);
  num_6();
  delay(Delay);
  num_7();
  delay(Delay);
  num_8();
  delay(Delay);
  num_9();
  delay(Delay);

  button();
}

void num_0() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, HIGH);
  digitalWrite(F, HIGH);
  digitalWrite(G, LOW);
}

void num_1() {
  digitalWrite(A, LOW);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, LOW);
  digitalWrite(E, LOW);
  digitalWrite(F, LOW);
  digitalWrite(G, LOW);
}

void num_2() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, LOW);
  digitalWrite(D, HIGH);
  digitalWrite(E, HIGH);
  digitalWrite(F, LOW);
  digitalWrite(G, HIGH);
}

void num_3() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, LOW);
  digitalWrite(F, LOW);
  digitalWrite(G, HIGH);
}

void num_4() {
  digitalWrite(A, LOW);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, LOW);
  digitalWrite(E, LOW);
  digitalWrite(F, HIGH);
  digitalWrite(G, HIGH);
}

void num_5() {
  digitalWrite(A, HIGH);
  digitalWrite(B, LOW);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, LOW);
  digitalWrite(F, HIGH);
  digitalWrite(G, HIGH);
}

void num_6() {
  digitalWrite(A, HIGH);
  digitalWrite(B, LOW);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, HIGH);
  digitalWrite(F, HIGH);
  digitalWrite(G, HIGH);
}

void num_7() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, LOW);
  digitalWrite(E, LOW);
  digitalWrite(F, LOW);
  digitalWrite(G, LOW);
}

void num_8() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, HIGH);
  digitalWrite(F, HIGH);
  digitalWrite(G, HIGH);
}

void num_9() {
  digitalWrite(A, HIGH);
  digitalWrite(B, HIGH);
  digitalWrite(C, HIGH);
  digitalWrite(D, HIGH);
  digitalWrite(E, LOW);
  digitalWrite(F, HIGH);
  digitalWrite(G, HIGH);
}
void button(){

  int Delay = analogRead(A0);
  int buttonState = digitalRead(ButtonPin);
  if (buttonState==LOW)
  {
    num_0();
  	delay(Delay);
  	num_1();
  	delay(Delay);
  	num_2();
  	delay(Delay);
  	num_3();
  	delay(Delay);
  	num_4();
  	delay(Delay);
  	num_5();
  	delay(Delay);
  	num_6();
  	delay(Delay);
  	num_7();
  	delay(Delay);
  	num_8();
  	delay(Delay);
  	num_9();
  	delay(Delay);

}
	else
{
	num_9();
  	delay(Delay);
  	num_8();
  	delay(Delay);
  	num_7();
  	delay(Delay);
  	num_6();
  	delay(Delay);
  	num_5();
  	delay(Delay);
  	num_4();
  	delay(Delay);
  	num_3();
  	delay(Delay);
  	num_2();
  	delay(Delay);
  	num_1();
  	delay(Delay);
}
}
# Out:
#   File "<ipython-input-1-bcf0927e8c28>", line 3
#     unsigned const int A = 13;
#              ^
# SyntaxError: invalid syntax
